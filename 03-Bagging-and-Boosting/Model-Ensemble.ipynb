# %% [markdown]
# - ### Name: Taher Mohamed Ahmed Saad
# - ### Section: 1
# - ### BN: 37

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# load the dataset using pandas
df = pd.read_excel("Concrete_Data.xlsx")

# %%
# split the dataframe into a training and testing splits with a 70% / 30% ratio
df_train, df_test = train_test_split(df, test_size=0.3, random_state=42) # Random is fixed for reproducability

# %%
df_train
# Out:
#      Cement (component 1)(kg in a m^3 mixture)  \
# 196                                     194.68
# 631                                     325.00
# 81                                      318.80
# 526                                     359.00
# 830                                     162.00
# ..                                         ...
# 87                                      286.30
# 330                                     246.83
# 466                                     190.34
# 121                                     475.00
# 860                                     314.00
#
#      Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 196                                                0.0
# 631                                                0.0
# 81                                               212.5
# 526                                               19.0
# 830                                              190.0
# ..                                                 ...
# 87                                               200.9
# 330                                                0.0
# 466                                                0.0
# 121                                              118.8
# 860                                                0.0
#
#      Fly Ash (component 3)(kg in a m^3 mixture)  \
# 196                                      100.52
# 631                                        0.00
# 81                                         0.00
# 526                                      141.00
# 830                                      148.00
# ..                                          ...
# 87                                         0.00
# 330                                      125.08
# 466                                      125.18
# 121                                        0.00
# 860                                      113.00
#
#      Water  (component 4)(kg in a m^3 mixture)  \
# 196                                     165.62
# 631                                     184.00
# 81                                      155.70
# 526                                     154.00
# 830                                     179.00
# ..                                         ...
# 87                                      144.70
# 330                                     143.30
# 466                                     166.61
# 121                                     181.10
# 860                                     170.00
#
#      Superplasticizer (component 5)(kg in a m^3 mixture)  \
# 196                                               7.48
# 631                                               0.00
# 81                                               14.30
# 526                                              10.91
# 830                                              19.00
# ..                                                 ...
# 87                                               11.20
# 330                                              11.99
# 466                                               9.88
# 121                                               8.90
# 860                                              10.00
#
#      Coarse Aggregate  (component 6)(kg in a m^3 mixture)  \
# 196                                             1006.4
# 631                                             1063.0
# 81                                               852.1
# 526                                              942.0
# 830                                              838.0
# ..                                                 ...
# 87                                              1004.6
# 330                                             1086.8
# 466                                             1079.0
# 121                                              852.1
# 860                                              925.0
#
#      Fine Aggregate (component 7)(kg in a m^3 mixture)  Age (day)  \
# 196                                             905.90         28
# 631                                             783.00          7
# 81                                              880.40          3
# 526                                             801.00          3
# 830                                             741.00         28
# ..                                                 ...        ...
# 87                                              803.70          3
# 330                                             800.89         14
# 466                                             798.90        100
# 121                                             781.50         28
# 860                                             783.00         28
#
#      Concrete compressive strength(MPa, megapascals)
# 196                                         25.724350
# 631                                         17.540269
# 81                                          25.200348
# 526                                         23.639177
# 830                                         33.756745
# ..                                                ...
# 87                                          24.400556
# 330                                         42.216615
# 466                                         33.563692
# 121                                         68.299493
# 860                                         38.458971
#
# [721 rows x 9 columns]

# %%
df_train.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                 721.000000
# mean                                  284.409681
# std                                   108.361334
# min                                   102.000000
# 25%                                   192.000000
# 50%                                   277.000000
# 75%                                   362.600000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                         721.000000
# mean                                           74.971886
# std                                            87.717335
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           145.000000
# max                                           359.400000
#
#        Fly Ash (component 3)(kg in a m^3 mixture)  \
# count                                  721.000000
# mean                                    52.006588
# std                                     63.707358
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                    117.540000
# max                                    195.000000
#
#        Water  (component 4)(kg in a m^3 mixture)  \
# count                                 721.000000
# mean                                  181.805576
# std                                    21.159956
# min                                   121.750000
# 25%                                   165.620000
# 50%                                   185.700000
# 75%                                   192.000000
# max                                   247.000000
#
#        Superplasticizer (component 5)(kg in a m^3 mixture)  \
# count                                         721.000000
# mean                                            6.125337
# std                                             6.046367
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             6.000000
# 75%                                            10.100000
# max                                            32.200000
#
#        Coarse Aggregate  (component 6)(kg in a m^3 mixture)  \
# count                                         721.000000
# mean                                          973.798128
# std                                            78.509208
# min                                           801.000000
# 25%                                           932.000000
# 50%                                           968.000000
# 75%                                          1040.000000
# max                                          1145.000000
#
#        Fine Aggregate (component 7)(kg in a m^3 mixture)   Age (day)  \
# count                                         721.000000  721.000000
# mean                                          771.636297   46.049931
# std                                            80.125492   61.650743
# min                                           594.000000    1.000000
# 25%                                           724.300000   14.000000
# 50%                                           778.450000   28.000000
# 75%                                           821.000000   56.000000
# max                                           992.600000  365.000000
#
#        Concrete compressive strength(MPa, megapascals)
# count                                        721.000000
# mean                                          36.152573
# std                                           16.803402
# min                                            2.331808
# 25%                                           23.890343
# 50%                                           35.076402
# 75%                                           46.247292
# max                                           82.599225

# %%
# extract the models input and targets from both the training and testing dataframes
def extract_Xy(df):
    df_numpy = df.to_numpy()
    return df_numpy[:, :-1], df_numpy[:, -1]

X_train, y_train = extract_Xy(df_train)
X_test, y_test = extract_Xy(df_test)

y_median = np.median(y_train)
print("Median value of the target:", y_median)

# Since we will treat this as a classification task, we will assume that
# the concrete is "strong" (y = True) if its compressive ratio is higher than the median
# otherwise, it is assumed to be "weak" (y = False)
y_train = y_train > y_median
y_test = y_test > y_median

# Now ~50% of the samples should be considered "strong" and the rest are considered "weak"
print(f"Percentage of 'strong' samples: {y_train.mean() * 100} %")

# Also, lets standardize the data since it improves the training process
X_mean = X_train.mean(axis=0)
X_std = X_train.std(axis=0)
X_train = (X_train - X_mean)/(1e-8 + X_std)
X_test = (X_test - X_mean)/(1e-8 + X_std)
# Out:
# Median value of the target: 35.076402024
# Percentage of 'strong' samples: 49.930651872399444 %

# %% [markdown]
# ## Bagging from Scratch

# %%
class GenericBagging:

    def __init__(self, n_estimators):
        self.n_estimators = n_estimators
        self.estimators = []
        self.initialize_estimators()
        self.samples_indexes = np.zeros((n_estimators, 300))
        
    def initialize_estimators(self):
        # initialize the given number of estimators
        # for _ in self.n_estimators:
        for _ in range(self.n_estimators):
            # Don't change the decision tree parameters
            self.estimators.append(DecisionTreeClassifier(max_depth=5, random_state=0))

    def generate_data_subset(self, X_data, y_data):
        # TODO: Generate bootstrap samples (with replacement)
        # Use a subset size of 300 samples
        indexes = np.random.choice(X_train.shape[0], 300, replace=True)
        X = X_data[indexes]
        y = y_data[indexes]
        return X, y, indexes    
        
    def fit(self, X, Y):
        # TODO: loop over each classifier and fit on random data subset
        for i in range(self.n_estimators):
            X_sample, y_sample, indexes = self.generate_data_subset(X, Y)
            self.estimators[i].fit(X_sample, y_sample)
            self.samples_indexes[i] = indexes

    def predict(self, X):
        # TODO: implement prediction function using majority vote
        votes = np.zeros((X.shape[0], len(self.estimators)))
        for i, estimator in enumerate(self.estimators):
            votes[:, i] = estimator.predict(X)
        return (votes.mean(axis=1) > 0.5).astype(int)
       
    def calculate_oob_error(self, X, Y):
        # TODO: calculate Out-of-Bag error
        # The out-of-bag (OOB) error is the average error for each training observation
        # calculated using predictions from the trees that do not contain this training observation
        # # in their respective bootstrap sample. 

        # Initialize an array to store the out-of-bag predictions for each sample
        oob_predictions = np.zeros((X.shape[0], len(self.estimators)))
        num_excuted_predictions = np.zeros(X.shape[0])

        for i, estimator in enumerate(self.estimators):
            # Find the indexes of samples not used in the i-th estimator
            oob_indexes = np.setdiff1d(np.arange(X.shape[0]), self.samples_indexes[i])

            # Make predictions for the out-of-bag samples using the i-th estimator
            oob_predictions[oob_indexes,i] = estimator.predict(X[oob_indexes])
            num_excuted_predictions[oob_indexes] += 1
        
        # Calculate the average prediction for the out-of-bag samples
        oob_predictions = oob_predictions.sum(axis=1) / num_excuted_predictions

        # Convert the predictions to binary values
        oob_predictions = (oob_predictions > 0.5).astype(int)

        # Calculate the out-of-bag error
        return 1 - accuracy_score(Y, oob_predictions)

# %%
def get_scores(n_estimators):
    # run model bagging and compute OOB error and test accuracy
    model = GenericBagging(n_estimators=n_estimators)
    model.fit(X_train, y_train)
    y_test_predict = model.predict(X_test)
    return model.calculate_oob_error(X_train, y_train), accuracy_score(y_test, y_test_predict)

# %%
def run_bagging():
    n_estimators_options = [5, 10, 50, 100, 200, 500]
    oob_errors = []
    test_accuracies = []
    for n_estimators in n_estimators_options:
        oob_error, test_accuracy = get_scores(n_estimators)
        oob_errors.append(oob_error)
        test_accuracies.append(test_accuracy)
    # TODO: plot the output scores against n_estimators
    plt.plot(n_estimators_options, test_accuracies, label='Test accuracy')
    plt.xlabel('n_estimators')
    plt.ylabel('Test accuracy')
    plt.legend()
    plt.show()
    plt.plot(n_estimators_options, oob_errors, label='OOB error')
    plt.xlabel('n_estimators')
    plt.ylabel('OOB error')
    plt.legend()
    plt.show()

# %%
run_bagging()
# Out:
# /var/folders/f9/pk0kkjn57c75lfw10h3kc0xh0000gn/T/ipykernel_75747/2289885526.py:57: RuntimeWarning: invalid value encountered in divide
#   oob_predictions = oob_predictions.sum(axis=1) / num_excuted_predictions

# %% [markdown]
# - ### As the number of estimators increases, a notable trend emerges: the Out-of-Bag (OOB) error decreases, while the accuracy of the model improves.
#
# - ### The OOB is good estimator for the performance as it keep decreasing as the accuracy increases.
#
# - ### As the number of estimators increases, the accuracy of the model improves but at the end it starts to decrease as the model becomes more complex and starts to overfit.

# %% [markdown]
# ## AdaBoost from Scratch

# %%
class GenericBoosting:

    def __init__(self, n_estimators):
        self.n_estimators = n_estimators

    def create_estimator(self):
        # create a decision stump as a weak estimator
        return DecisionTreeClassifier(max_depth=1, random_state=0)

    def fit_and_predict(self, X_train, Y_train, X_test, Y_test):
        # apply AdaBoost on weak estimators
        # convert the targets to {-1, 1} instead of {0, 1}
        Y_train = 2 * Y_train - 1
        Y_test = 2 * Y_test - 1
                
        ## initialize the training and test data with empty array placeholders
        pred_train = np.empty((self.n_estimators, X_train.shape[0]))
        pred_test = np.empty((self.n_estimators, X_test.shape[0]))
        
        # initialize weights
        W = np.ones((X_train.shape[0],)) / X_train.shape[0]

        # loop over the boosting iterations 
        for idx in range(self.n_estimators): 

            # create and fit a new decision stump
            model = self.create_estimator().fit(X_train, Y_train, sample_weight=W)

            # predict classes for the training data and test data
            pred_train_idx = model.predict(X_train)
            pred_test_idx = model.predict(X_test)

            # TODO: calculate the miss Indicator
            # miss_indicator = None
            miss_indicator = np.abs(pred_train_idx - Y_train) / 2

            # TODO: calculate the error for the current classifier
            # cls_err =  None
            cls_err = np.sum(W * miss_indicator)

            # TODO: calculate current classifier weight
            # cls_alpha = None
            cls_alpha = np.log((1 - cls_err) / cls_err) / 2

            # TODO: update the weights 
            # W = None
            W = W * np.exp(-cls_alpha * Y_train * pred_train_idx)
            
            # TODO: add to the overall predictions
            # pred_train[idx] = None
            # pred_test[idx] = None
            pred_train[idx] = cls_alpha * pred_train_idx
            pred_test[idx] = cls_alpha * pred_test_idx

            # normalize weights 
            W = W / np.sum(W)

        # TODO: return accuracy on train and test sets
        # train_accuracy = None
        # test_accuracy = None
        train_accuracy = np.mean(np.sign(np.sum(pred_train, axis=0)) == Y_train)
        test_accuracy = np.mean(np.sign(np.sum(pred_test, axis=0)) == Y_test)
        
        return train_accuracy, test_accuracy

# %%
def get_scores(n_estimators):
    # run model boosting and compute train and test accuracy
    model = GenericBoosting(n_estimators=n_estimators)
    train_accuracy, test_accuracy = model.fit_and_predict(X_train, y_train, X_test, y_test)
    return train_accuracy, test_accuracy

# %%
def run_boosting():
    n_estimators_options = [5, 10, 50, 100, 200, 500]
    train_accuracies = []
    test_accuracies = []
    for n_estimators in n_estimators_options:
        train_accuracy, test_accuracy = get_scores(n_estimators)
        train_accuracies.append(train_accuracy)
        test_accuracies.append(test_accuracy)
    # TODO: plot the output scores against n_estimators
    plt.plot(n_estimators_options, train_accuracies, label='Train accuracy')
    plt.plot(n_estimators_options, test_accuracies, label='Test accuracy')
    plt.xlabel('Number of estimators')
    plt.ylabel('Accuracy score')
    plt.title('Boosting performance')
    plt.legend()
    plt.show()

# %%
run_boosting()

# %% [markdown]
# - ### As we increases the number of estimators it is visible that the train accuracy always increses. that is becuase latter models try to learn more from the mistakes of the previous models.
#
# - ### But the test accuracy increases to a certain point and then decreases. This is probably due to model starting to overfit the training data as it becomes more comlex.
